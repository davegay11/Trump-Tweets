# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
import csv
with open("./data/clean_data/citizens_united.csv", 'rb') as f:
    reader = csv.reader(f)
    linenumber = 1
    try:
        for row in reader:
            linenumber += 1
    except Exception as e:
        print (("Error line %d: %s %s" % (linenumber, str(type(e)), e.message)))
# Out:
# Error line 1771: <class '_csv.Error'> new-line character seen in unquoted field - do you need to open the file in universal-newline mode?
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   if __name__ == '__main__':

# %%
# Create our sentiment analyzer
sid = SentimentIntensityAnalyzer()

df = pd.read_csv("./data/clean_data/andypuzder.csv", header=0)
tweets = list(df['clean_text'])

# %%
df
# Out:
#                                                  source  \
# 0                                                 other
# 1                                                 other
# 2     Event: http://t.co/scXejT1a proceeds benefitte...
# 3                                                 other
# 4                                                 other
# 5                                                 other
# 6                                                 other
# 7                                                 other
# 8                                                 other
# 9                                                 other
# 10                                                other
# 11                                                other
# 12                                                other
# 13                                                other
# 14                                                other
# 15                                                other
# ...

# %%
df['compound_polarity'] = df.apply(lambda row: str(row))

# %%
df
# Out:
#                                                  source  \
# 0                                                 other
# 1                                                 other
# 2     Event: http://t.co/scXejT1a proceeds benefitte...
# 3                                                 other
# 4                                                 other
# 5                                                 other
# 6                                                 other
# 7                                                 other
# 8                                                 other
# 9                                                 other
# 10                                                other
# 11                                                other
# 12                                                other
# 13                                                other
# 14                                                other
# 15                                                other
# ...

# %%
df['compound_polarity'] = df['clean_text'].apply(lambda x: sid.polarity_scores(str(x))['compound'])

# %%
df
# Out:
#                                                  source  \
# 0                                                 other
# 1                                                 other
# 2     Event: http://t.co/scXejT1a proceeds benefitte...
# 3                                                 other
# 4                                                 other
# 5                                                 other
# 6                                                 other
# 7                                                 other
# 8                                                 other
# 9                                                 other
# 10                                                other
# 11                                                other
# 12                                                other
# 13                                                other
# 14                                                other
# 15                                                other
# ...
