# %%
import pandas as pd
import json
import csv
import re
import nltk

# In this file we take the raw data (found in trumps twitter archive) and 
# combine it into a single file, which we manipulate accordingly.

# %%
def get_raw_data(filename):
    '''Get the raw json data downloaded from the tweepy API'''
    data = None
    with open(filename) as f:
        data = json.load(f)
    return data

# %%
data_files = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']
tweet_years = [get_raw_data('./data/trump_tweet_data_archive/master_' + f + '.json') for f in data_files]
tweets = []
for tweet_year in tweet_years:
    tweets += tweet_year

# %%
def get_input_fields(tweets):
    '''Get all of the fields in the data (rows in the csv header). Note that for the csv 
    file we only include fields that we can put in a csv file
    '''
    all_fields = []
    csv_fields = []
    for key, value in tweets[0].iteritems():
        valid_types = (int, float, unicode, str, bool)
        if any([isinstance(value, valid_type) for valid_type in valid_types]):
            csv_fields.append(key)
        all_fields.append(key)
    return (all_fields, csv_fields)

# %%
all_fields, csv_fields = get_input_fields(tweets)
print(all_fields)
print(csv_fields)
# Out:
# [u'contributors', u'truncated', u'text', u'is_quote_status', u'in_reply_to_status_id', u'id', u'favorite_count', u'source', u'retweeted', u'coordinates', u'entities', u'in_reply_to_screen_name', u'in_reply_to_user_id', u'retweet_count', u'id_str', u'favorited', u'user', u'geo', u'in_reply_to_user_id_str', u'lang', u'created_at', u'in_reply_to_status_id_str', u'place']
# [u'truncated', u'text', u'is_quote_status', u'id', u'favorite_count', u'source', u'retweeted', u'retweet_count', u'id_str', u'favorited', u'lang', u'created_at']

# %%
def json_2_csv(json, filename, fields):
    '''Convert a python dict to csv and write it to a file'''
    fail_count = 0
    with open(filename, 'w') as f:
        # First erase all the previous contents of the file
        f.truncate()
        # create the csv writer object
        writer = csv.writer(f)
        rows = 0
        for entry in json:
            if rows == 0:
                header = fields
                writer.writerow(header)
                rows += 1
            try:
                vals = [entry[key] for key in fields]
                writer.writerow(vals)
            except UnicodeEncodeError:
                fail_count += 1
    print "Could not parse the contents of %d entries" % fail_count

# %%
# Save the tweets in a csv format
json_2_csv(tweets, "trumps_tweets.csv", csv_fields)
# Out:
# Could not parse the contents of 3854 entries

# %%
# Now lets read the contents of the file with pandas
data = pd.read_csv("trumps_tweets.csv", header=0)

# %%
# Let's examine the data...everything looks good
data
# Out:
#       truncated                                               text  \
# 0         False  Trump International Tower in Chicago ranked 6t...
# 1         False  Wishing you and yours a very Happy and Bountif...
# 2         False  Donald Trump Partners with TV1 on New Reality ...
# 3         False  Hear Donald Trump discuss big gov spending, ba...
# 4         False  Watch video of Ivanka Trump sharing business a...
# 5         False  - Read what Donald Trump has to say about daug...
# 6         False  "A lot of people have imagination, but can't e...
# 7         False  Read Donald Trump's Top Ten Tips for Success: ...
# 8         False  - More hysterical DSRL videos featuring Donald...
# 9         False  - Donald Trump bids to buy the Oreo Double Stu...
# 10        False  Reminder: The Miss Universe competition will b...
# 11        False  Watch the Miss Universe competition LIVE from ...
# 12        False  -- Watch Donald Trump's recent appearance on T...
# 13        False  Ivanka is now on Twitter - You can follow her ...
# 14        False  Browse Donald Trump's Summer Reading List for ...
# 15        False  Check out a list of Donald Trump's books for s...
# 16        False  Congrats to winners from around the world who ...
# 17        False  Donald Trump backs 'Apprentice' Randal Pinkett...
# 18        False  "Be aware of things that seem inexplicable bec...
# 19        False  Here's to a safe and happy Independence Day fo...
# 20        False  Watch a powerful and frank interview with Dona...
# 21        False  - Wishing a Happy Father's Day to all the Dad'...
# 22        False  RE: FB Vanity URLs: SF Chronicle - "David Beck...
# 23        False  Today is Donald Trump's Birthday! Send him you...
# 24        False  Last week to enter the "Think Like A Champion"...
# 25        False  Check out Donald Trump's new iGoogle Showcase ...
# 26        False  "You have to know when to call it quits and wh...
# 27        False  Read an excerpt from Think Like A Champion by ...
# 28        False  "Your higher self is in direct opposition to y...
# 29        False  Did you know Donald Trump is on Facebook? http...
# ...         ...                                                ...
# 26715     False  ...time for Republicans &amp; Democrats to get...
# 26716     False  ...do the typical political thing and BLAME. T...
# 26717     False  The Democrats, lead by head clown Chuck Schume...
# 26718     False  Jackie Evancho's album sales have skyrocketed ...
# 26719     False  massive increases of ObamaCare will take place...
# 26720     False  like the 116% hike in Arizona. Also, deductibl...
# 26721     False  Republicans must be careful in that the Dems o...
# 26722     False  things they did and said (like giving the ques...
# 26723     False  Somebody hacked the DNC but why did they not h...
# 26724     False  Thank you to Ford for scrapping a new plant in...
# 26725     False  Julian Assange said "a 14 year old could have ...
# 26726     False  The "Intelligence" briefing on so-called "Russ...
# 26727     False  I will be having a general news conference on ...
# 26728     False  "Trump is already delivering the jobs he promi...
# 26729     False  There should be no further releases from Gitmo...
# 26730     False  Instead of driving jobs and wealth away, AMERI...
# 26731     False  "@DanScavino: Ford to scrap Mexico plant, inve...
# 26732     False  ........may be, their number one act and prior...
# 26733     False  With all that Congress has to work on, do they...
# 26734     False  The Democrat Governor.of Minnesota said "The A...
# 26735     False  People must remember that ObamaCare just doesn...
# 26736     False  General Motors is sending Mexican made model o...
# 26737     False  China has been taking out massive amounts of m...
# 26738     False  North Korea just stated that it is in the fina...
# 26739     False  I thought and felt I would win big, easily ove...
# 26740     False  Various media outlets and pundits say that I t...
# 26741     False  @CNN just released a book called "Unprecedente...
# 26742     False  Chicago murder rate is record setting - 4,331 ...
# 26743     False  Well, the New Year begins. We will, together, ...
# 26744     False  RT @DonaldJTrumpJr: Happy new year everyone. #...
#
#       is_quote_status                  id  favorite_count  \
# 0               False          6312794445               6
# 1               False          6090839867              11
# 2               False          5775731054               3
# 3               False          5069623974               2
# 4               False          4862580190              10
# 5               False          4629116949               4
# 6               False          4472353826              30
# 7               False          3982428551              30
# 8               False          3688564134               6
# 9               False          3627328938               3
# 10              False          3498743628               4
# 11              False          3450626731               3
# 12              False          3427503309               5
# 13              False          3308367056              15
# 14              False          3124382438              14
# 15              False          2891870497              19
# 16              False          2779566791               3
# 17              False          2650952843               2
# 18              False          2614325575              15
# 19              False          2475429091               2
# 20              False          2403435685               1
# 21              False          2266041769               0
# 22              False          2222067805               9
# 23              False          2165353946               5
# 24              False          2080633709               0
# 25              False          2019316195              14
# 26              False          1949899014              19
# 27              False          1936022874               4
# 28              False          1924074459              15
# 29              False          1894284587              10
# ...               ...                 ...             ...
# 26715           False  816979231217483776           38365
# 26716           False  816977937731878912           26900
# 26717           False  816977032433270784           28115
# 26718           False  816718880731234304           13225
# 26719           False  816652088662958082           19962
# 26720           False  816645831659061248           19857
# 26721           False  816644321768312832           20151
# 28     Tue May 26 14:42:01 +0000 2009
# 29     Sat May 23 16:11:19 +0000 2009
# ...                               ...
# 26715  Thu Jan 05 12:06:42 +0000 2017
# 26716  Thu Jan 05 12:01:33 +0000 2017
# 26717  Thu Jan 05 11:57:57 +0000 2017
# 26718  Wed Jan 04 18:52:09 +0000 2017
# 26719  Wed Jan 04 14:26:45 +0000 2017
# 26720  Wed Jan 04 14:01:53 +0000 2017
# 26721  Wed Jan 04 13:55:53 +0000 2017
# 26722  Wed Jan 04 13:31:32 +0000 2017
# 26723  Wed Jan 04 13:27:03 +0000 2017
# 26724  Wed Jan 04 13:19:09 +0000 2017
# 26725  Wed Jan 04 12:22:38 +0000 2017
# 26726  Wed Jan 04 01:14:52 +0000 2017
# 26727  Tue Jan 03 23:58:31 +0000 2017
# 26728  Tue Jan 03 18:44:47 +0000 2017
# 26729  Tue Jan 03 17:20:43 +0000 2017
# 26730  Tue Jan 03 17:00:11 +0000 2017
# 26731  Tue Jan 03 16:44:13 +0000 2017
# 26732  Tue Jan 03 15:07:41 +0000 2017
# 26733  Tue Jan 03 15:03:29 +0000 2017
# 26734  Tue Jan 03 12:51:15 +0000 2017
# 26735  Tue Jan 03 12:46:33 +0000 2017
# 26736  Tue Jan 03 12:30:05 +0000 2017
# 26737  Mon Jan 02 23:47:12 +0000 2017
# 26738  Mon Jan 02 23:05:44 +0000 2017
# 26739  Mon Jan 02 18:44:04 +0000 2017
# 26740  Mon Jan 02 18:37:10 +0000 2017
# 26741  Mon Jan 02 18:32:29 +0000 2017
# 26742  Mon Jan 02 17:31:17 +0000 2017
# 26743  Mon Jan 02 14:40:10 +0000 2017
# 26744  Sun Jan 01 06:49:33 +0000 2017
#
# [26745 rows x 12 columns]

# %%
# The shape of the data (num_rows, num_fields)
data.shape
# Out:
# (26745, 12)

# %%
# Now lets create a bag of words representation of our data for basic NLP
# Start by trying the process on one of our text entries. We bascially 
# replace anything that is not a letter with a space.
letters_only = re.sub("[^a-zA-Z]", " ", data["text"][0]).lower().split()  # The text to search
print letters_only
# Out:
# ['trump', 'international', 'tower', 'in', 'chicago', 'ranked', 'th', 'tallest', 'building', 'in', 'world', 'by', 'council', 'on', 'tall', 'buildings', 'urban', 'habitat', 'http', 'bit', 'ly', 'sqvqq']

# %%
# Hmm looks like there was a link which we will need to deal with. We'll
# get back to that later.

# We need to get rid of stop words (common words that don't carry much
# meaning). To do this we use nltk: (download the stopwords corpus)
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
# Let's check to see that the stopwords were downloaded
from nltk.corpus import stopwords # Import the stop word list
print stopwords.words("english")
# Out:
# [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', u'should', u'now', u'd', u'll', u'm', u'o', u're', u've', u'y', u'ain', u'aren', u'couldn', u'didn', u'doesn', u'hadn', u'hasn', u'haven', u'isn', u'ma', u'mightn', u'mustn', u'needn', u'shan', u'shouldn', u'wasn', u'weren', u'won', u'wouldn']

# %%
# Looks good. Now we need to filter out these words from our representation
letters_only = [w for w in letters_only if w not in stopwords.words('english')]
print(letters_only)
# Out:
# ['trump', 'international', 'tower', 'chicago', 'ranked', 'th', 'tallest', 'building', 'world', 'council', 'tall', 'buildings', 'urban', 'habitat', 'http', 'bit', 'ly', 'sqvqq']

# %%
# Let's put it all together in a function
def clean_text(text):
    '''Function to remove punctuation and stopwords from text. Note that we keep
    the @ symbol as a hashtag adds meaning'''
    # First let's get rid of links, as they will mess up our bag or words...for 
    # example, one of the links is "https://t.co/BSp685Q9Qf https://t.co/K7yeBZsf6r'",
    # which just turns into gibberish
    # source: http://stackoverflow.com/questions/6883049/regex-to-find-urls-in-string-in-python
    link_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    no_links = re.sub(link_regex, " ", text)
    word_list = re.sub("[^@a-zA-Z]", " ", no_links).lower().split()
    # Searching a set is faster in python
    stops = set(stopwords.words("english"))
    # blacklist of words that we should ignore...for example amp is really just &,
    # so it appears a ton but has no semantic value
    blacklist = ['amp']
    clean_list = [w for w in word_list if (w not in stops and w not in blacklist)]
    return " ".join( clean_list )

# %%
# Checking that it works:
print data["text"][2]
print clean_text(data["text"][2])
# Out:
# Donald Trump Partners with TV1 on New Reality Series Entitled, Omarosa's Ultimate Merger: http://tinyurl.com/yk5m3lc
# donald trump partners tv new reality series entitled omarosa ultimate merger

# %%
# We now add a clean_text column to our data frame
data['clean_text'] = data.apply(lambda x: clean_text(x['text']), axis=1)

# %%
# Let's also change the source column to just be "android" or "iphone",
# as this is easier to parse. First we check all the different possible
# sources
set(data['source'])
# Out:
# {'<a href="http://beta.twitlonger.com" rel="nofollow">TwitLonger Beta</a>',
#  '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#  '<a href="http://twitter.com" rel="nofollow">Twitter QandA</a>',
#  '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#  '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#  '<a href="http://www.Neatly.me" rel="nofollow">Neatly For BlackBerry 10</a>',
#  '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#  '<a href="http://www.twitlonger.com" rel="nofollow">Twitlonger</a>',
#  '<a href="http://www.twitter.com" rel="nofollow">Twitter Mirror for iPad</a>',
#  '<a href="http://www.twitter.com" rel="nofollow">Twitter for BlackBerry</a>',
#  '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#  '<a href="https://ads.twitter.com" rel="nofollow">Twitter Ads</a>',
#  '<a href="https://dev.twitter.com/docs/tfw" rel="nofollow">Twitter for Websites</a>',
#  '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#  '<a href="https://periscope.tv" rel="nofollow">Periscope</a>',
#  '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>'}

# %%
# Now that we know all of the sources, let's map them to a shorter string
def get_phone(source):
    '''Return what medium the tweet was sent from'''
    if source is None:
        return ""
    # The source will now be one of the following text fields
    source_list = ['instagram', 'web', 'ipad', 'android', 'iphone', 'ads', \
                   'periscope', 'media', 'qanda', 'twitlonger', 'vine', 'blackberry' \
                   'facebook', 'tweetdeck', 'websites', 'm5']
    stripped = re.match('<a .*>(.*?)</a>', source).group(1).lower().split()
    return "".join([w for w in stripped if w in source_list])
# Apply this to the source column
data['source'] = data["source"].apply(lambda x: get_phone(x))

# %%
# Let's also get rid of the id_str field, as it is pretty useless
data.drop('id_str', axis=1, inplace=True)

# %%
data
# Out:
#       truncated                                               text  \
# 0         False  Trump International Tower in Chicago ranked 6t...
# 1         False  Wishing you and yours a very Happy and Bountif...
# 2         False  Donald Trump Partners with TV1 on New Reality ...
# 3         False  Hear Donald Trump discuss big gov spending, ba...
# 4         False  Watch video of Ivanka Trump sharing business a...
# 5         False  - Read what Donald Trump has to say about daug...
# 6         False  "A lot of people have imagination, but can't e...
# 7         False  Read Donald Trump's Top Ten Tips for Success: ...
# 8         False  - More hysterical DSRL videos featuring Donald...
# 9         False  - Donald Trump bids to buy the Oreo Double Stu...
# 10        False  Reminder: The Miss Universe competition will b...
# 11        False  Watch the Miss Universe competition LIVE from ...
# 12        False  -- Watch Donald Trump's recent appearance on T...
# 13        False  Ivanka is now on Twitter - You can follow her ...
# 14        False  Browse Donald Trump's Summer Reading List for ...
# 15        False  Check out a list of Donald Trump's books for s...
# 16        False  Congrats to winners from around the world who ...
# 17        False  Donald Trump backs 'Apprentice' Randal Pinkett...
# 18        False  "Be aware of things that seem inexplicable bec...
# 19        False  Here's to a safe and happy Independence Day fo...
# 20        False  Watch a powerful and frank interview with Dona...
# 21        False  - Wishing a Happy Father's Day to all the Dad'...
# 22        False  RE: FB Vanity URLs: SF Chronicle - "David Beck...
# 23        False  Today is Donald Trump's Birthday! Send him you...
# 24        False  Last week to enter the "Think Like A Champion"...
# 25        False  Check out Donald Trump's new iGoogle Showcase ...
# 26        False  "You have to know when to call it quits and wh...
# 27        False  Read an excerpt from Think Like A Champion by ...
# 28        False  "Your higher self is in direct opposition to y...
# 29        False  Did you know Donald Trump is on Facebook? http...
# ...         ...                                                ...
# 26715     False  ...time for Republicans &amp; Democrats to get...
# 26716     False  ...do the typical political thing and BLAME. T...
# 26717     False  The Democrats, lead by head clown Chuck Schume...
# 26718     False  Jackie Evancho's album sales have skyrocketed ...
# 26719     False  massive increases of ObamaCare will take place...
# 26720     False  like the 116% hike in Arizona. Also, deductibl...
# 26721     False  Republicans must be careful in that the Dems o...
# 26722     False  things they did and said (like giving the ques...
# 26723     False  Somebody hacked the DNC but why did they not h...
# 26724     False  Thank you to Ford for scrapping a new plant in...
# 26725     False  Julian Assange said "a 14 year old could have ...
# 26726     False  The "Intelligence" briefing on so-called "Russ...
# 26727     False  I will be having a general news conference on ...
# 26728     False  "Trump is already delivering the jobs he promi...
# 26729     False  There should be no further releases from Gitmo...
# 26730     False  Instead of driving jobs and wealth away, AMERI...
# 26731     False  "@DanScavino: Ford to scrap Mexico plant, inve...
# 26732     False  ........may be, their number one act and prior...
# 26733     False  With all that Congress has to work on, do they...
# 26734     False  The Democrat Governor.of Minnesota said "The A...
# 26735     False  People must remember that ObamaCare just doesn...
# 26736     False  General Motors is sending Mexican made model o...
# 26737     False  China has been taking out massive amounts of m...
# 26738     False  North Korea just stated that it is in the fina...
# 26739     False  I thought and felt I would win big, easily ove...
# 26740     False  Various media outlets and pundits say that I t...
# 26741     False  @CNN just released a book called "Unprecedente...
# 26742     False  Chicago murder rate is record setting - 4,331 ...
# 26743     False  Well, the New Year begins. We will, together, ...
# 26744     False  RT @DonaldJTrumpJr: Happy new year everyone. #...
#
#       is_quote_status                  id  favorite_count   source retweeted  \
# 0               False          6312794445               6      web     False
# 1               False          6090839867              11      web     False
# 2               False          5775731054               3      web     False
# 3               False          5069623974               2      web     False
# 4               False          4862580190              10      web     False
# 5               False          4629116949               4      web     False
# 6               False          4472353826              30      web     False
# 7               False          3982428551              30      web     False
# 8               False          3688564134               6      web     False
# 9               False          3627328938               3      web     False
# 10              False          3498743628               4      web     False
# 11              False          3450626731               3      web     False
# 12              False          3427503309               5      web     False
# 13              False          3308367056              15      web     False
# 14              False          3124382438              14      web     False
# 15              False          2891870497              19      web     False
# 16              False          2779566791               3      web     False
# 17              False          2650952843               2      web     False
# 18              False          2614325575              15      web     False
# 19              False          2475429091               2      web     False
# 20              False          2403435685               1      web     False
# 21              False          2266041769               0      web     False
# 22              False          2222067805               9      web     False
# 23              False          2165353946               5      web     False
# 24              False          2080633709               0      web     False
# 25              False          2019316195              14      web     False
# 26              False          1949899014              19      web     False
# 27              False          1936022874               4      web     False
# 28              False          1924074459              15      web     False
# 29              False          1894284587              10      web     False
# ...               ...                 ...             ...      ...       ...
# 26715           False  816979231217483776           38365  android     False
# 26716           False  816977937731878912           26900  android     False
# 26717           False  816977032433270784           28115  android     False
# 26718           False  816718880731234304           13225      web     False
# 26719           False  816652088662958082           19962  android     False
# 26720           False  816645831659061248           19857  android     False
# 26721           False  816644321768312832           20151  android     False
# 26722           False  816638194468999169           23073  android     False
# 26723           False  816637064708030464           21023  android     False
# 26724           False  816635078067490816           39855  android     False
# 26725           False  816620855958601730           32684  android     False
# 26726           False  816452807024840704           29889  android     False
# 26727           False  816433590892429312            1310  android     False
# 26728           False  816354639859871745            2573   iphone     False
# 26729           False  816333480409833472            2842  android     False
# 26730           False  816328314759606272            8920   iphone     False
# 26731           False  816324295781740544            5875   iphone     False
# 26732           False  816300003442495488           15405  android     False
# 26733           False  816298944456232960           14663  android     False
# 26734           False  816265668958031872            1918  android     False
# 26735           False  816264484629184513            1565  android     False
# 26736           False  816260343391514624             975  android     False
# 26737           False  816068355555815424            4005  android     False
# 26738           False  816057920223846400            7664  android     False
# 26739           False  815992069412057088           20993  android     False
# 26740           False  815990335318982656           16763  android     False
# 26741           False  815989154555297792            3523  android     False
# 26742           False  815973752785793024           28701  android     False
# 26743           False  815930688889352192           80789  android     False
# 26744           False  815449868739211265               0   iphone     False
#
#        retweet_count favorited lang                      created_at  \
# 0                 33     False   en  Thu Dec 03 19:39:09 +0000 2009
# 1                 13     False   en  Thu Nov 26 19:55:38 +0000 2009
# 2                  5     False   en  Mon Nov 16 21:06:10 +0000 2009
# 3                  2     False   en  Thu Oct 22 13:57:04 +0000 2009
# 4                  4     False   en  Wed Oct 14 14:13:17 +0000 2009
# 5                  1     False   en  Mon Oct 05 14:37:38 +0000 2009
# 26739           4891     False   en  Mon Jan 02 18:44:04 +0000 2017
# 26740           3627     False   en  Mon Jan 02 18:37:10 +0000 2017
# 26741           1175     False   en  Mon Jan 02 18:32:29 +0000 2017
# 26742           8575     False   en  Mon Jan 02 17:31:17 +0000 2017
# 26743          19320     False   en  Mon Jan 02 14:40:10 +0000 2017
# 26744           4902     False   en  Sun Jan 01 06:49:33 +0000 2017
#
#                                               clean_text
# 0      trump international tower chicago ranked th ta...
# 1                   wishing happy bountiful thanksgiving
# 2      donald trump partners tv new reality series en...
# 3      hear donald trump discuss big gov spending ban...
# 4      watch video ivanka trump sharing business advi...
# 5      read donald trump say daughter ivanka upcoming...
# 6      lot people imagination execute execute imagina...
# 7                 read donald trump top ten tips success
# 8      hysterical dsrl videos featuring donald trump ...
# 9      donald trump bids buy oreo double stuf racing ...
# 10     reminder miss universe competition live bahama...
# 11     watch miss universe competition live bahamas s...
# 12     watch donald trump recent appearance late show...
# 13     ivanka twitter follow @ivankatrump terrific we...
# 14     browse donald trump summer reading list busine...
# 15     check list donald trump books summer reading t...
# 16     congrats winners around world entered think li...
# 17     donald trump backs apprentice randal pinkett n...
# 18     aware things seem inexplicable big step toward...
# 19     safe happy independence day one enjoy donald j...
# 20     watch powerful frank interview donald trump ec...
# 21     wishing happy father day dad champion today ev...
# 22     fb vanity urls sf chronicle david beckham one ...
# 23         today donald trump birthday send b day wishes
# 24     last week enter think like champion signed boo...
# 25          check donald trump new igoogle showcase page
# 26     know call quits keep moving forward donald j t...
# 27       read excerpt think like champion donald j trump
# 28     higher self direct opposition comfort zone don...
# 29           know donald trump facebook become fan today
# ...                                                  ...
# 26715  time republicans democrats get together come h...
# 26716  typical political thing blame fact obamacare l...
# 26717  democrats lead head clown chuck schumer know b...
# 26718  jackie evancho album sales skyrocketed announc...
# 26719  massive increases obamacare take place year de...
# 26720  like hike arizona also deductibles high practi...
# 26721  republicans must careful dems failed obamacare...
# 26722  things said like giving questions debate h tot...
# 26723  somebody hacked dnc hacking defense like rnc r...
# 26724  thank ford scrapping new plant mexico creating...
# 26725  julian assange said year old could hacked pode...
# 26726  intelligence briefing called russian hacking d...
# 26727  general news conference january eleventh n c t...
# 26728     trump already delivering jobs promised america
# 26729  releases gitmo extremely dangerous people allo...
# 26730  instead driving jobs wealth away america becom...
# 26731  @danscavino ford scrap mexico plant invest mic...
# 26732  may number one act priority focus tax reform h...
# 26733  congress work really make weakening independen...
# 26734  democrat governor minnesota said affordable ca...
# 26735  people must remember obamacare work affordable...
# 26736  general motors sending mexican made model chev...
# 26737  china taking massive amounts money wealth u to...
# 26738  north korea stated final stages developing nuc...
# 26739  thought felt would win big easily fabled cance...
# 26740  various media outlets pundits say thought goin...
# 26741  @cnn released book called unprecedented explor...
# 26742  chicago murder rate record setting shooting vi...
# 26743   well new year begins together make america great
# 26744  rt @donaldjtrumpjr happy new year everyone new...
#
# [26745 rows x 12 columns]

# %%
# Looks good. Now let's save the cleaned data to both csv and json format in a separate
# clean_data directory. Note that we need to specify the records format for the json
# or else it will output in a strange way
data.to_json('./clean_data/clean_tweets.json', orient="records")
data.to_csv('./clean_data/clean_tweets.csv', index=False)

# %%
len(data)
# Out:
# 26745
